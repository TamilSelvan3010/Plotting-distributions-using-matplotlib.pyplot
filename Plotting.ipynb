# %% [markdown]
# ## PLOTTING DISTRIBUTIONS USING MATPLOTLIB.PYPLOT AND SEABORN

# %%
import pandas as pd
import matplotlib.pyplot as mat

# %%
import seaborn as sea

# %% [markdown]
# # ABOUT THE DATASET

# %% [markdown]
# ##### This classic dataset originally contained the prices and other attributes of almost 54,000 diamonds. However, 14184 of those seem to be the same diamonds, measure from a different angle. This can be found out but checking for duplicated value when disregarding the variables x, y, z, depth and table, which are dependent on the angle.

# %%
diamond=pd.read_csv('G:/pyton/diamonds.csv')

# %% [markdown]
# #### To read a csv file in jupyter notebook

# %%
diamond
# Out:
#        carat           cut color clarity  depth  table  price  value  values  \
# 0       0.23      b'Ideal'  b'E'  b'SI2'   61.5   55.0    326   3.95    3.98
# 1       0.21    b'Premium'  b'E'  b'SI1'   59.8   61.0    326   3.89    3.84
# 2       0.23       b'Good'  b'E'  b'VS1'   56.9   65.0    327   4.05    4.07
# 3       0.29    b'Premium'  b'I'  b'VS2'   62.4   58.0    334   4.20    4.23
# 4       0.31       b'Good'  b'J'  b'SI2'   63.3   58.0    335   4.34    4.35
# ...      ...           ...   ...     ...    ...    ...    ...    ...     ...
# 53935   0.72      b'Ideal'  b'D'  b'SI1'   60.8   57.0   2757   5.75    5.76
# 53936   0.72       b'Good'  b'D'  b'SI1'   63.1   55.0   2757   5.69    5.75
# 53937   0.70  b'Very Good'  b'D'  b'SI1'   62.8   60.0   2757   5.66    5.68
# 53938   0.86    b'Premium'  b'H'  b'SI2'   61.0   58.0   2757   6.15    6.12
# 53939   0.75      b'Ideal'  b'D'  b'SI2'   62.2   55.0   2757   5.83    5.87
#
#        valuess
# 0         2.43
# ...

# %%
diamond.describe()
# Out:
#               carat         depth         table         price         value  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#              values       valuess
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# #### In this dataset ,it shows us the basic statistical data of dataset,Like Count, Mean, STD, min, 25th percentile, 50th percentile, 75th percentile and max functions.

# %%
mat.boxplot(diamond['depth'])
mat.show()

# %% [markdown]
# #### We have taken boxplot for ''depth'' variable in the dataset, where there are outliers in the 80 and 45, It displays us the boxplot is plotted b/w the value 60 to 65 .

# %%
mat.boxplot(diamond['depth'])
mat.yscale('log')
mat.show()

# %% [markdown]
# #### In this dataset, We have taken log scale in order to display the boxplot, where it gives clear view to understand about dataset in a better way.

# %%
mat.hist(diamond['table'],color='g')
mat.show()

# %% [markdown]
# #### We have displayed a histogram for the variable,'table' it displays us that the histogram reaches its peak in 54 to 58 values ,where the peak value is 35000 and there are no values after 69 to 90 and above.

# %%
mat.hist(diamond['table'])
mat.yscale('log')
mat.show()

# %% [markdown]
# #### By taking the log scale for the histogram , it displays us there are data present in 90 to 93 and 46 to 49 ,it helps us to understand or to view the data set in a better way.

# %%
mat.scatter(diamond['depth'],diamond['table'],color='y')
mat.show()

# %% [markdown]
# #### In Scatter plot we have taken two variables''depth'' and ''table'', there is outlier extreme high value which is placed in 93 in yaxis,the maximum value of data in the dataset is occured between the values of (50 to 69) in yaxis and (55 to 68) in xaxis but there are small amount of data is present across the Scatter plot.

# %%
sea.distplot(diamond['price'],color='r')
mat.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### We have displayed distplot for the variable "price" in which the data reaches its peak around the price  of 475 to 500, the dataset displays that from price around 500 once price increases and began to decreases to 5000 and again it displays huge decrease in price range of 10000 to 20000  .

# %%
sea.distplot(diamond['price'][:5000],rug=True,color='r')
mat.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### by using the rug it has highlighted the data which has values in price variable in the bottom of the values, from the values around 2900 to 3800 the variable has more data in the dataset but it reaches its peak value around 550 to 600 value in this we have take data which is less 5000 in the price variable.

# %%
sea.distplot(diamond['price'],hist=False,color='r')
mat.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### by using the hist function and giving false it show us only the line in the data and it does not displays the bar in the plots

# %%
sea.boxplot(diamond['carat'])
mat.title('carat')
mat.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### There are outliers high extreme value in the dataset in which plotted in 5 carat of diamond but the boxplot which has more data is plotted in the values of 0 to 1 carat of diamond but there are also outliers from 3 to 4 carat of diamond which is plotted in the dataset.

# %%
sea.boxplot(y=diamond['carat'])
mat.title('carat')
mat.show()

# %% [markdown]
# #### we have displayed the dataset in the vertical view in order to have clear view of understanding about dataset.

# %%
sea.jointplot('carat','price',diamond,kind='reg',color='r')
mat.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### In this jointplot we have Taken price and carat of the diamond ,in which 0.20 to 0.22 carat diamonds are sold at the price around 300 to 500 and 0.23 of carat diamonds are sold at the price of 300 to 700 ,0.24 carat of diamonds are being sold at the price of 350 to 750 and 0.25 carat of diamonds are sold at the price of 350 to 750, 0.26 carat of diamonds are sold at the price of  around 350 to 800, 0.27 to 0.29 carat of diamonds are being sold at price of 350 to 800 , and there is a outlier in 0.24 where it takes at the price of 900

# %%
diamond=diamond[(diamond.carat<0.30)&(diamond.price<1000)]
sea.jointplot('carat','price',diamond,kind="resid",color='k')
mat.show()

# %% [markdown]
# #### in this jointplot we have chosen a certain value and condition for the two variables "carat" and "price" where price less 1000 and carat less than 0.30 in which there is a outlier plotted in price of 900 in 0.24 carat, in this condition there are average amount of value in 0.23 to 0.29 carat  but 0.20 to 0.22 carat has minimum value , the price range for the carat from 0.23 to 0.28 displays us it has the price range around 320 to 600 in an averge manner.

# %%
diamond=diamond[(diamond.carat<0.30)&(diamond.price<1000)]
sea.jointplot(x='carat',y='price',data=diamond,kind='hex',color='g')
mat.show()

# %% [markdown]
# #### we have displayed the variables of carat and price with a certain condition and also using color and kind where in this we have given color as red and kind as hexagon by using hexagon when the hexagon becomes darker it shows us there are maximum values are present in that if it becomes lighter it shows us there are minimum value are there, in this the most the dark hexagon is plotted in the value of (0.23,500) (carat,price) it also does displays the histograms of the respective variables.

# %%
#subplot 1
mat.subplot(3,3,1)
#mat.title('CARAT')
sea.distplot(diamond['carat'])

#subplot 2
mat.subplot(3,3,2)
#mat.title('PRICE')
sea.distplot(diamond['price'])

#subplot3
mat.subplot(3,3,3)
#mat.title('VALUE')
sea.distplot(diamond['value'])

mat.tight_layout()
mat.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# #### we have created a subplots for three variables"carat,price,value".

# %%
x = list(diamond.iloc[:,5])
y = list(diamond.iloc[:,7])
mat.bar(x,y,color='g')
mat.title("table vs depth")
mat.xlabel('table')
mat.ylabel('depth')
# Out:
# Text(0, 0.5, 'depth')

# %% [markdown]
# #### in this barplot we have taken x as table and y as depth in which we have also used iloc function to locate specific rows and columns in the dataset and changed the color of the barplot to red ,In this barplot there is no values present in the table variable around 45 to 52 and maximum value in the data is present in 54 to 56 but the other data has values.

# %%
x = list(diamond.iloc[:,5])
y = list(diamond.iloc[:,7])
mat.bar(x,y,color='g')
mat.title("table vs depth")
mat.xlabel('table')
mat.ylabel('depth')
mat.xticks(color='g', rotation='85', fontweight='bold', fontsize='12', horizontalalignment='right')
# Out:
# (array([40., 45., 50., 55., 60., 65., 70.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# #### we have changed the fontsize,fontweight, horizontal alignment,color and rotation of displayed barplot.
